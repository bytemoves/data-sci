# %%
# !pip install fredapi

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import plotly.express as px
from fredapi import Fred

plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 10)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
fred_key = '4736d16fd8188a6067a72566222ec044'  # Replace with your actual FRED API key
plt.show()

# %%
fred = Fred(fred_key )

# %%
fred

# %%
#search for ecomonic data
sp_search = fred.search('S$P')
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\Hp\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1282, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1281 """Send a complete request to the server."""
# -> 1282 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\Hp\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1328, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
# ...

# %%
sp_search = fred.search('S$P', order_by='popularity')

# %%
sp_search
# Out:
#                                           id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2                    BAMLH0A0HYM2     2023-06-07   2023-06-07
# CSUSHPINSA                        CSUSHPINSA     2023-06-07   2023-06-07
# BAMLH0A0HYM2EY                BAMLH0A0HYM2EY     2023-06-07   2023-06-07
# SP500                                  SP500     2023-06-07   2023-06-07
# CSUSHPISA                          CSUSHPISA     2023-06-07   2023-06-07
# ...                                      ...            ...          ...
# DDEM01UAA156NWDB            DDEM01UAA156NWDB     2023-06-07   2023-06-07
# DDEM01TZA156NWDB            DDEM01TZA156NWDB     2023-06-07   2023-06-07
# CRDQHKAPUBIS                    CRDQHKAPUBIS     2023-06-07   2023-06-07
# CRDQSEAPUBIS                    CRDQSEAPUBIS     2023-06-07   2023-06-07
# M0422AUS000NYM267NNBR  M0422AUS000NYM267NNBR     2023-06-07   2023-06-07
#
#                                                                    title  \
# ...

# %%
sp500 = fred.get_series(series_id='sp500')

# %%
#multiple data series
unemploymant_results = fred.search('unemployment')

# %%
unemploymant_results
# Out:
#                     id realtime_start realtime_end  \
# series id
# UNRATE          UNRATE     2023-06-07   2023-06-07
# UNRATENSA    UNRATENSA     2023-06-07   2023-06-07
# CCSA              CCSA     2023-06-07   2023-06-07
# NROU              NROU     2023-06-07   2023-06-07
# UNEMPLOY      UNEMPLOY     2023-06-07   2023-06-07
# ...                ...            ...          ...
# PABUCK5URN  PABUCK5URN     2023-06-07   2023-06-07
# ILCOLE3URN  ILCOLE3URN     2023-06-07   2023-06-07
# OHHOCK3URN  OHHOCK3URN     2023-06-07   2023-06-07
# PACHES5URN  PACHES5URN     2023-06-07   2023-06-07
# VAARLI0URN  VAARLI0URN     2023-06-07   2023-06-07
#
#                                                 title observation_start  ...  \
# series id                                                                ...
# UNRATE                              Unemployment Rate        1948-01-01  ...
# UNRATENSA                           Unemployment Rate        1948-01-01  ...
# ...

# %%
unemploymant_state = fred.search('unemployment state')

# %%
unrate = fred.get_series("UNRATE")

# %%
unrate
# Out:
# 1948-01-01    3.4
# 1948-02-01    3.8
# 1948-03-01    4.0
# 1948-04-01    3.9
# 1948-05-01    3.5
#              ...
# 2023-01-01    3.4
# 2023-02-01    3.6
# 2023-03-01    3.5
# 2023-04-01    3.4
# 2023-05-01    3.7
# Length: 905, dtype: float64

# %%
matplotlib.unrate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 matplotlib.unrate()
#
# NameError: name 'matplotlib' is not defined
